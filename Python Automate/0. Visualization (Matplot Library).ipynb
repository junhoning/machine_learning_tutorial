# %%
import os 
from glob import glob   # 파일 

import numpy as np  # array
from PIL import Image  # PIL과 Image의 I는 대문자  # 이미지 열기 

import matplotlib.pyplot as plt  # 시각화 
# %matplotlib inline

# %% [markdown]
# # Image

# %%
path
# Out:
# 'C:/workspace/images\\dog.jpg'

# %%
pil_image = Image.open(path)
image = np.array(pil_image)

# %%
image.shape
# Out:
# (572, 767, 3)

# %%
plt.imshow(image)  # 2차원(흑백)이나 3차원(channel: 3 또는 4)
plt.show()

# %%
bw_pil = pil_image.convert("L")
bw_image = np.array(bw_pil)
bw_image.shape
# Out:
# (572, 767)

# %%
# bw_image = image[:,:,0]
# bw_image.shape

# %%
plt.imshow(bw_image, 'gray')
plt.show()

# %%
plt.imshow(bw_image, 'jet')
plt.colorbar()
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.imshow(bw_image)
plt.subplot(1, 2, 2)
plt.imshow(image)
plt.show()

# %%
path_2 = path.replace('.jpg', '_2.jpg')
path_2
# Out:
# 'C:/workspace/images\\dog_2.jpg'

# %%
pil_2 = Image.open(path_2)
image_2 = np.array(pil_2)
image_2.shape
# Out:
# (486, 729, 3)

# %%
image.shape
# Out:
# (572, 767, 3)

# %%
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(image_2)
plt.show()

# %%
plt.imshow(image)
plt.imshow(image_2, alpha=0.5)
plt.show()
